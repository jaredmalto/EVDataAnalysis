# %%
import pandas as pd
import matplotlib.pyplot as plt

#import csv as dataframe
df = pd.read_csv("Battery Test Data.csv")

# %%
internal_resist_measure_1 = df["Internal Resistance Measure 1"]

# %%
quality_parameter = df["Quality Parameter"]

# %%
# use a scatter plot to find correlation
plt.scatter(internal_resist_measure_1, quality_parameter)
# rename axes
plt.xlabel("Internal Resistance Measure 1")
plt.ylabel("Quality Parameter")
# Out:
# Text(0, 0.5, 'Quality Parameter')

# %%
internal_resist_measure_2 = df["Internal Resistance Measure 2"]

# %%
plt.scatter(internal_resist_measure_2, quality_parameter)
plt.xlabel("Internal Resistance Measure 2")
plt.ylabel("Quality Parameter")
# Out:
# Text(0, 0.5, 'Quality Parameter')

# %%
df2 = df[["Internal Resistance Measure 1", "Quality Parameter"]]

# %%
data = pd.DataFrame(df2)

# %%
# Describe distribution between IRM1 and QP
data.corr()
# Out:
#                                Internal Resistance Measure 1  \
# Internal Resistance Measure 1                       1.000000
# Quality Parameter                                  -0.221478
#
#                                Quality Parameter
# Internal Resistance Measure 1          -0.221478
# Quality Parameter                       1.000000

# %%
df3 = df[["Internal Resistance Measure 2", "Quality Parameter"]]

# %%
# Describe distribution between IRM2 and QP
data2 = pd.DataFrame(df3)

# %%
data2.corr()
# Out:
#                                Internal Resistance Measure 2  \
# Internal Resistance Measure 2                       1.000000
# Quality Parameter                                  -0.307218
#
#                                Quality Parameter
# Internal Resistance Measure 2          -0.307218
# Quality Parameter                       1.000000
